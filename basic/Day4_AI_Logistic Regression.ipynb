# %% [markdown]
# # Logistic Regression Classification
#  Logistic Regression भनेको के हो?
# 👉 यो एकदमै popular classification algorithm हो
# 👉 यो continuous output दिँदैन (जस्तो Linear Regression)
# 👉 बरु यसले भन्छ:
#
# Yes कि No
#
# Pass कि Fail
#
# 1 कि 0
#
# Spam कि Not Spam
#
# Yeslay Sigmoid function प्रयोग गर्छ
#  Sigmoid Function
# यो एक mathematical formula हो, जसले कुनै पनि number लाई 0 र 1 बीचमा convert गर्छ
#
# Formula:
#
# sigmoid(x) = 1 / (1 + e^(-x))
# 👉 यो function ले probability निकाल्छ
# 👉 जस्तो: "तिमीले 5 घण्टा पढ्यौ भने पास हुने chance 82%"

# %%
# Python बाट Sigmoid Function plot गरौँ

import numpy as np 
import matplotlib.pyplot as plt

def sigmoid(x):
    return 1 /(1 + np.exp(-x))

#

x = np.linspace(-10, 10, 100) # x को लागि −10 देखि 10 सम्मका 100 वटा number बनाइएको हो

# linspace ले continuous range बनाउँछ
y = sigmoid(x)

plt.plot(x, y, color='green')
plt.title("Sigmoid Function")
plt.xlabel("Input")
plt.ylabel("probability")
plt.grid(True)
plt.show()

'''जब x धेरै negative हुन्छ ⇒ sigmoid almost 0 हुन्छ

जब x positive जान्छ ⇒ sigmoid 1 तिर पुग्छ

बीचमा x = 0 मा sigmoid value हुन्छ 0.5'''
# Out:
# 'जब x धेरै negative हुन्छ ⇒ sigmoid almost 0 हुन्छ\n\nजब x positive जान्छ ⇒ sigmoid 1 तिर पुग्छ\n\nबीचमा x = 0 मा sigmoid value हुन्छ 0.5'

# %% [markdown]
# # Logistic Regression को Simple Example
# तिमीले 1 देखि 7 घण्टा पढ्ने डेटा छ।
# la aaba  एउटा model बनायौ: कति घण्टा पढेपछि पास हुने सम्भावना छ?

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression

# study hours ( input)
X = np.array([1,2,3,4,5,6,7]).reshape(-1, 1)

# labels : 0 = fail , 1 = pass
y = np.array([0,0,0,1,1,1,1])

# train the model
model = LogisticRegression()
model.fit(X, y)

# predict new data input

X_test = np.array([2,5,6]).reshape(-1, 1)
predictions = model.predict(X_test)
print("Predictions", predictions)
# Out:
# Predictions [0 1 1]

# %% [markdown]
# [0 1 1]
# # 2 घण्टा पढ्ने fail
# # 5 घण्टा पढ्ने पास
# # 6 घण्टा पढ्ने पास

# %% [markdown]
#  # Evaluation — कति राम्रो काम गर्‍यो model ले?

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

y_true = [0, 1, 1, 0, 1]      # Actual labels
y_pred = [0, 1, 0, 0, 1]      # Predicted labels

print("Confusion Matrix:\n", confusion_matrix(y_true, y_pred))
print("Accuracy:", accuracy_score(y_true, y_pred))
print("Precision:", precision_score(y_true, y_pred))
print("Recall:", recall_score(y_true, y_pred))
# Out:
# Confusion Matrix:
#  [[2 0]
#  [1 2]]
# Accuracy: 0.8
# Precision: 1.0
# Recall: 0.6666666666666666

# %% [markdown]
# Q: Logistic Regression ले continuous value predict गर्छ कि discrete class?
#
# 👉 A:
#
# Logistic Regression ले probability predict गर्छ, र त्यसलाई threshold गरेर class मा बद्लिन्छ (जस्तै 0.5 भन्दा माथि भने 1)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

# Input data: study hours
X = np.array([1, 2, 3, 4, 5, 6, 7]).reshape(-1, 1)

# Labels: 0 = fail, 1 = pass
y = np.array([0, 0, 0, 1, 1, 1, 1])

# Train model
model = LogisticRegression()
model.fit(X, y)

# Plotting decision boundary
x_range = np.linspace(0, 8, 300).reshape(-1, 1)  # Smooth curve input
probabilities = model.predict_proba(x_range)[:, 1]  # Probability of passing (class 1)

plt.figure(figsize=(8, 5))
plt.plot(x_range, probabilities, color='green', label='Pass Probability')
plt.scatter(X, y, color='blue', label='Training Data')

# Predicted points
X_test = np.array([2, 5, 6]).reshape(-1, 1)
predictions = model.predict(X_test)
plt.scatter(X_test, predictions, color='red', marker='x', s=100, label='Test Predictions')

# Styling
plt.title("Logistic Regression: Pass/Fail Based on Study Hours")
plt.xlabel("Hours Studied")
plt.ylabel("Probability of Passing")
plt.legend()
plt.grid(True)
plt.ylim(-0.1, 1.1)
plt.show()

# Console prediction output
print("Predictions:", predictions)
# Out:
# Predictions: [0 1 1]
