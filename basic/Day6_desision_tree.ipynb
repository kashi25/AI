# %%
import pandas as pd

# Dummy dataset of fruits
data = {
    "Weight": [100, 150, 120, 80, 200, 130, 90],
    "Size": [7, 8, 7, 6, 9, 8, 6],
    "Color_Score": [8.5, 9.0, 7.5, 6.0, 9.5, 8.0, 6.5],
    "Quality": ["Good", "Good", "Good", "Bad", "Good", "Good", "Bad"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Weight  Size  Color_Score Quality
# 0     100     7          8.5    Good
# 1     150     8          9.0    Good
# 2     120     7          7.5    Good
# 3      80     6          6.0     Bad
# 4     200     9          9.5    Good
# 5     130     8          8.0    Good
# 6      90     6          6.5     Bad

# %%
# lets' create a decision 
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

 # split features and target
X = df[["Weight" ,"Size" , "Color_Score"]]
y = df["Quality"]

# now time to train the model
tree = DecisionTreeClassifier(max_depth=3, random_state=0)
tree.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %%
# visualize tree

plt.Figure(figsize=(10,6))
plot_tree(tree, filled=True, feature_names=X.columns, class_names=tree.classes_)
plt.title("Fruit Quality Decision Tree")
plt.show()

# %%
# test prediction 
test_sample = [[80, 6, 6.4]]
pred = tree.predict(test_sample)
print("predicted Quality:", pred[0])
# Out:
# predicted Quality: Bad
# C:\Users\Acer\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
